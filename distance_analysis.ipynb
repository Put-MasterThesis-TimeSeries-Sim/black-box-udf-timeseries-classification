# %%
import pandas as pd

# %%
distance_df = pd.read_csv("comparison_distance.csv")

# %% [markdown]
# ## CPU - not standardised and not smoothed

# %%
filter1 = distance_df["dataType"]=="CPU"
filter2 = distance_df["is_standardised"]==0
filter3 = distance_df["is_smoothed"]==0

filtered = distance_df[filter1 & filter2 & filter3]
filtered
# Out:
#     dataType               function1  snapshot1               function2  \
# 0        CPU             aggregation          1             aggregation
# 2        CPU             aggregation          0             aggregation
# 4        CPU             aggregation          0             aggregation
# 6        CPU             aggregation          1             aggregation
# 26       CPU              filtration          1              filtration
# 28       CPU              filtration          0              filtration
# 30       CPU              filtration          0              filtration
# 32       CPU              filtration          1              filtration
# 52       CPU             aggregation          0              filtration
# 54       CPU             aggregation          0              filtration
# 56       CPU             aggregation          1              filtration
# 58       CPU              filtration          1             aggregation
# 60       CPU              filtration          2             aggregation
# 62       CPU              filtration          2             aggregation
# 82       CPU              filtration          1              filtration
# 84       CPU              filtration          0              filtration
# 86       CPU              filtration          0              filtration
# 88       CPU              filtration          1              filtration
# 108      CPU  filtration-aggregation          1  filtration-aggregation
# 110      CPU  filtration-aggregation          0  filtration-aggregation
# 112      CPU  filtration-aggregation          0  filtration-aggregation
# 114      CPU  filtration-aggregation          1  filtration-aggregation
# 134      CPU             aggregation          0              filtration
# 136      CPU             aggregation          0              filtration
# 138      CPU             aggregation          1              filtration
# 140      CPU              filtration          1             aggregation
# 142      CPU              filtration          2             aggregation
# 144      CPU              filtration          2             aggregation
# 164      CPU             aggregation          0  filtration-aggregation
# 166      CPU             aggregation          0  filtration-aggregation
# 168      CPU             aggregation          1  filtration-aggregation
# 188      CPU              filtration          0  filtration-aggregation
# 190      CPU              filtration          0  filtration-aggregation
# 192      CPU              filtration          1  filtration-aggregation
#
#      snapshot2  euclidean  dtw-python-distance  dtw-python-normalizedDistance  \
# 0            1        0.0                  0.0                       0.000000
# 2            1        0.0               3901.6                       3.684230
# 4            2        0.0               3646.5                       3.255804
# 6            2        0.0               4249.4                       4.035518
# 26           1        0.0                  0.0                       0.000000
# 28           1        0.0               2648.3                       8.740264
# 30           2        0.0               2387.3                       8.203780
# 32           2        0.0               2127.8                       7.337241
# 52           1        0.0               4820.7                       6.751681
# 54           2        0.0               5344.4                       7.613105
# 56           2        0.0               4265.2                       6.716850
# 58           0        0.0               4820.7                       6.751681
# 60           0        0.0               5344.4                       7.613105
# 62           1        0.0               4265.2                       6.716850
# 82           1        0.0                  0.0                       0.000000
# 84           1        0.0               2648.3                       8.740264
# 86           2        0.0               2387.3                       8.203780
# 88           2        0.0               2127.8                       7.337241
# 108          1        0.0                  0.0                       0.000000
# 110          1        0.0               4134.8                       3.345307
# 112          2        0.0               4235.5                       3.460376
# 114          2        0.0               3669.9                       3.429813
# 134          1        0.0               4820.7                       6.751681
# 136          2        0.0               5344.4                       7.613105
# 138          2        0.0               4265.2                       6.716850
# 140          0        0.0               4820.7                       6.751681
# 142          0        0.0               5344.4                       7.613105
# 144          1        0.0               4265.2                       6.716850
# 164          1        0.0               4126.2                       3.737500
# 166          2        0.0               4412.6                       4.040842
# 168          2        0.0               3798.8                       3.706146
# 188          1        0.0               4083.1                       5.891919
# 190          2        0.0               4392.0                       6.449339
# 192          2        0.0               4114.6                       6.050882
#
#      dtaidistance  is_standardised  is_smoothed
# 0        0.000000                0            0
# 2      313.896432                0            0
# 4      282.452669                0            0
# 6      349.830173                0            0
# 26       0.000000                0            0
# 28     264.891431                0            0
# 30     282.100443                0            0
# 32     194.066715                0            0
# 52     450.453971                0            0
# 54     546.665474                0            0
# 56     474.829496                0            0
# 58     450.453971                0            0
# 60     546.665474                0            0
# 62     474.829496                0            0
# 82       0.000000                0            0
# 84     264.891431                0            0
# 86     282.100443                0            0
# 88     194.066715                0            0
# 108      0.000000                0            0
# 110    335.371943                0            0
# 112    332.291483                0            0
# 114    315.707190                0            0
# 134    450.453971                0            0
# 136    546.665474                0            0
# 138    474.829496                0            0
# 140    450.453971                0            0
# 142    546.665474                0            0
# 144    474.829496                0            0
# 164    346.896152                0            0
# 166    400.134477                0            0
# 168    333.409298                0            0
# 188    393.513392                0            0
# 190    446.849841                0            0
# 192    437.904111                0            0

# %% [markdown]
# ## CPU - standardised but not smoothed

# %%
filter1 = distance_df["dataType"]=="CPU"
filter2 = distance_df["is_standardised"]==1
filter3 = distance_df["is_smoothed"]==0

filtered = distance_df[filter1 & filter2 & filter3]
filtered
# Out:
#     dataType               function1  snapshot1               function2  \
# 8        CPU             aggregation          0             aggregation
# 10       CPU             aggregation          0             aggregation
# 12       CPU             aggregation          1             aggregation
# 34       CPU              filtration          0              filtration
# 36       CPU              filtration          0              filtration
# 38       CPU              filtration          1              filtration
# 64       CPU             aggregation          0              filtration
# 66       CPU             aggregation          0              filtration
# 68       CPU             aggregation          1              filtration
# 90       CPU              filtration          0              filtration
# 92       CPU              filtration          0              filtration
# 94       CPU              filtration          1              filtration
# 116      CPU  filtration-aggregation          0  filtration-aggregation
# 118      CPU  filtration-aggregation          0  filtration-aggregation
# 120      CPU  filtration-aggregation          1  filtration-aggregation
# 146      CPU             aggregation          0              filtration
# 148      CPU             aggregation          0              filtration
# 150      CPU             aggregation          1              filtration
# 170      CPU             aggregation          0  filtration-aggregation
# 172      CPU             aggregation          0  filtration-aggregation
# 174      CPU             aggregation          1  filtration-aggregation
# 194      CPU              filtration          0  filtration-aggregation
# 196      CPU              filtration          0  filtration-aggregation
# 198      CPU              filtration          1  filtration-aggregation
#
#      snapshot2  euclidean  dtw-python-distance  dtw-python-normalizedDistance  \
# 8            1        0.0            65.720545                       0.062059
# 10           2        0.0            48.110368                       0.042956
# 12           2        0.0            76.148065                       0.072315
# 34           1        0.0            22.714090                       0.074964
# 36           2        0.0            25.567979                       0.087862
# 38           2        0.0            25.166735                       0.086782
# 64           1        0.0           166.580874                       0.233307
# 66           2        0.0           187.240761                       0.266725
# 68           2        0.0           155.171484                       0.244365
# 90           1        0.0            22.714090                       0.074964
# 92           2        0.0            25.567979                       0.087862
# 94           2        0.0            25.166735                       0.086782
# 116          1        0.0            98.117707                       0.079383
# 118          2        0.0            98.586281                       0.080544
# 120          2        0.0            46.961005                       0.043889
# 146          1        0.0           166.580874                       0.233307
# 148          2        0.0           187.240761                       0.266725
# 150          2        0.0           155.171484                       0.244365
# 170          1        0.0            55.211715                       0.050011
# 172          2        0.0            61.790233                       0.056584
# 174          2        0.0            55.917454                       0.054554
# 194          1        0.0           156.317598                       0.225567
# 196          2        0.0           155.232324                       0.227948
# 198          2        0.0           142.969425                       0.210249
#
#      dtaidistance  is_standardised  is_smoothed
# 8        3.929070                1            0
# 10       3.527208                1            0
# 12       4.339602                1            0
# 34       2.102231                1            0
# 36       2.461230                1            0
# 38       1.888128                1            0
# 64      11.350521                1            0
# 66      10.702191                1            0
# 68       9.291161                1            0
# 90       2.102231                1            0
# 92       2.461230                1            0
# 94       1.888128                1            0
# 116      4.967189                1            0
# 118      4.752177                1            0
# 120      3.696863                1            0
# 146     11.350521                1            0
# 148     10.702191                1            0
# 150      9.291161                1            0
# 170      4.232421                1            0
# 172      4.845150                1            0
# 174      3.889126                1            0
# 194      9.843346                1            0
# 196     10.022037                1            0
# 198     10.313804                1            0

# %% [markdown]
# ## CPU - smoothed but not standardised

# %%
filter1 = distance_df["dataType"]=="CPU"
filter2 = distance_df["is_standardised"]==0
filter3 = distance_df["is_smoothed"]==1

filtered = distance_df[filter1 & filter2 & filter3]
filtered
# Out:
#     dataType               function1  snapshot1               function2  \
# 14       CPU             aggregation          0             aggregation
# 16       CPU             aggregation          0             aggregation
# 18       CPU             aggregation          1             aggregation
# 40       CPU              filtration          0              filtration
# 42       CPU              filtration          0              filtration
# 44       CPU              filtration          1              filtration
# 70       CPU             aggregation          0              filtration
# 72       CPU             aggregation          0              filtration
# 74       CPU             aggregation          1              filtration
# 96       CPU              filtration          0              filtration
# 98       CPU              filtration          0              filtration
# 100      CPU              filtration          1              filtration
# 122      CPU  filtration-aggregation          0  filtration-aggregation
# 124      CPU  filtration-aggregation          0  filtration-aggregation
# 126      CPU  filtration-aggregation          1  filtration-aggregation
# 152      CPU             aggregation          0              filtration
# 154      CPU             aggregation          0              filtration
# 156      CPU             aggregation          1              filtration
# 176      CPU             aggregation          0  filtration-aggregation
# 178      CPU             aggregation          0  filtration-aggregation
# 180      CPU             aggregation          1  filtration-aggregation
# 200      CPU              filtration          0  filtration-aggregation
# 202      CPU              filtration          0  filtration-aggregation
# 204      CPU              filtration          1  filtration-aggregation
#
#      snapshot2  euclidean  dtw-python-distance  dtw-python-normalizedDistance  \
# 14           1        0.0              1039.23                       0.981331
# 16           2        0.0               936.97                       0.836580
# 18           2        0.0              1094.13                       1.039060
# 40           1        0.0               889.18                       2.934587
# 42           2        0.0              1019.53                       3.503540
# 44           2        0.0               431.43                       1.487690
# 70           1        0.0              3987.75                       5.585084
# 72           2        0.0              3967.69                       5.651980
# 74           2        0.0              3689.92                       5.810898
# 96           1        0.0               889.18                       2.934587
# 98           2        0.0              1019.53                       3.503540
# 100          2        0.0               431.43                       1.487690
# 122          1        0.0              1475.31                       1.193617
# 124          2        0.0              1407.33                       1.149779
# 126          2        0.0              1265.74                       1.182935
# 152          1        0.0              3987.75                       5.585084
# 154          2        0.0              3967.69                       5.651980
# 156          2        0.0              3689.92                       5.810898
# 176          1        0.0              1409.39                       1.276621
# 178          2        0.0              1907.43                       1.746731
# 180          2        0.0              1296.13                       1.264517
# 200          1        0.0              3832.63                       5.530491
# 202          2        0.0              3784.15                       5.556755
# 204          2        0.0              3592.76                       5.283471
#
#      dtaidistance  is_standardised  is_smoothed
# 14      82.897720                0            1
# 16      53.317121                0            1
# 18      81.049968                0            1
# 40     157.123020                0            1
# 42     164.949576                0            1
# 44      39.581124                0            1
# 70     442.713849                0            1
# 72     440.222134                0            1
# 74     451.027324                0            1
# 96     157.123020                0            1
# 98     164.949576                0            1
# 100     39.581124                0            1
# 122    119.232303                0            1
# 124    116.496954                0            1
# 126     92.419527                0            1
# 152    442.713849                0            1
# 154    440.222134                0            1
# 156    451.027324                0            1
# 176    116.712576                0            1
# 178    186.915798                0            1
# 180    112.807162                0            1
# 200    473.689194                0            1
# 202    543.634203                0            1
# 204    526.941191                0            1

# %% [markdown]
# ## CPU - standardised and smoothed

# %%
filter1 = distance_df["dataType"]=="CPU"
filter2 = distance_df["is_standardised"]==1
filter3 = distance_df["is_smoothed"]==1

filtered = distance_df[filter1 & filter2 & filter3]
filtered
# Out:
#     dataType               function1  snapshot1               function2  \
# 20       CPU             aggregation          0             aggregation
# 22       CPU             aggregation          0             aggregation
# 24       CPU             aggregation          1             aggregation
# 46       CPU              filtration          0              filtration
# 48       CPU              filtration          0              filtration
# 50       CPU              filtration          1              filtration
# 76       CPU             aggregation          0              filtration
# 78       CPU             aggregation          0              filtration
# 80       CPU             aggregation          1              filtration
# 102      CPU              filtration          0              filtration
# 104      CPU              filtration          0              filtration
# 106      CPU              filtration          1              filtration
# 128      CPU  filtration-aggregation          0  filtration-aggregation
# 130      CPU  filtration-aggregation          0  filtration-aggregation
# 132      CPU  filtration-aggregation          1  filtration-aggregation
# 158      CPU             aggregation          0              filtration
# 160      CPU             aggregation          0              filtration
# 162      CPU             aggregation          1              filtration
# 182      CPU             aggregation          0  filtration-aggregation
# 184      CPU             aggregation          0  filtration-aggregation
# 186      CPU             aggregation          1  filtration-aggregation
# 206      CPU              filtration          0  filtration-aggregation
# 208      CPU              filtration          0  filtration-aggregation
# 210      CPU              filtration          1  filtration-aggregation
#
#      snapshot2  euclidean  dtw-python-distance  dtw-python-normalizedDistance  \
# 20           1        0.0                22.54                       0.021284
# 22           2        0.0                11.07                       0.009884
# 24           2        0.0                23.77                       0.022574
# 46           1        0.0                 7.55                       0.024917
# 48           2        0.0                11.50                       0.039519
# 50           2        0.0                10.10                       0.034828
# 76           1        0.0               167.76                       0.234958
# 78           2        0.0               188.75                       0.268875
# 80           2        0.0               152.98                       0.240913
# 102          1        0.0                 7.55                       0.024917
# 104          2        0.0                11.50                       0.039519
# 106          2        0.0                10.10                       0.034828
# 128          1        0.0                33.80                       0.027346
# 130          2        0.0                37.47                       0.030613
# 132          2        0.0                14.94                       0.013963
# 158          1        0.0               167.76                       0.234958
# 160          2        0.0               188.75                       0.268875
# 162          2        0.0               152.98                       0.240913
# 182          1        0.0                17.00                       0.015399
# 184          2        0.0                26.05                       0.023855
# 186          2        0.0                19.28                       0.018810
# 206          1        0.0               149.74                       0.216075
# 208          2        0.0               146.86                       0.215653
# 210          2        0.0               133.94                       0.196971
#
#      dtaidistance  is_standardised  is_smoothed
# 20       1.325971                1            1
# 22       0.655362                1            1
# 24       1.441839                1            1
# 46       1.223520                1            1
# 48       1.468196                1            1
# 50       0.608276                1            1
# 76      11.101455                1            1
# 78      11.567917                1            1
# 80       9.677634                1            1
# 102      1.223520                1            1
# 104      1.468196                1            1
# 106      0.608276                1            1
# 128      1.709795                1            1
# 130      2.007237                1            1
# 132      1.115661                1            1
# 158     11.101455                1            1
# 160     11.567917                1            1
# 162      9.677634                1            1
# 182      1.450000                1            1
# 184      2.222859                1            1
# 186      1.372516                1            1
# 206      9.955240                1            1
# 208      9.940609                1            1
# 210     10.179597                1            1
