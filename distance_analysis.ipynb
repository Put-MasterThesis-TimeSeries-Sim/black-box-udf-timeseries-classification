# %%
import pandas as pd

# %%
distance_df = pd.read_csv("comparison_distance.csv")

# %%
def bold_style(val):
    print(val)
    f = "font-weight: bold"
    #condition
    print(val['function1'])
    m = val['function1'] != val['function2']
    # DataFrame of styles
    df1 = pd.DataFrame('', index=val.index, columns=val.columns)
    # set columns by condition
    df1 = df1.mask(m, f)
    return df1

# %% [markdown]
# ## CPU - not normalized and not smoothed

# %%
filter1 = distance_df["dataType"]=="CPU"
filter2 = distance_df["is_normalized"]==0
filter3 = distance_df["is_smoothed"]==0

filtered = distance_df[filter1 & filter2 & filter3]
#filtered.style.apply(bold_style,axis = 1)
filtered.sort_values(by=['dtw-python-distance'], inplace=True)
filtered
# Out:
# C:\Users\anna\miniconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#     dataType               function1  snapshot1               function2  \
# 0        CPU             aggregation          1             aggregation
# 52       CPU  filtration-aggregation          1  filtration-aggregation
# 26       CPU              filtration          1              filtration
# 30       CPU              filtration          0              filtration
# 28       CPU              filtration          0              filtration
# 32       CPU              filtration          1              filtration
# 4        CPU             aggregation          0             aggregation
# ...

# %% [markdown]
# ## CPU - normalized but not smoothed

# %%
filter1 = distance_df["dataType"]=="CPU"
filter2 = distance_df["is_normalized"]==1
filter3 = distance_df["is_smoothed"]==0

filtered = distance_df[filter1 & filter2 & filter3]
filtered.sort_values(by=['dtw-python-distance'], inplace=True)
filtered
# Out:
# C:\Users\anna\miniconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#     dataType               function1  snapshot1               function2  \
# 36       CPU              filtration          0              filtration
# 34       CPU              filtration          0              filtration
# 38       CPU              filtration          1              filtration
# 10       CPU             aggregation          0             aggregation
# 64       CPU  filtration-aggregation          1  filtration-aggregation
# 118      CPU             aggregation          1  filtration-aggregation
# 8        CPU             aggregation          0             aggregation
# ...

# %% [markdown]
# ## CPU - smoothed but not normalized

# %%
filter1 = distance_df["dataType"]=="CPU"
filter2 = distance_df["is_normalized"]==0
filter3 = distance_df["is_smoothed"]==1

filtered = distance_df[filter1 & filter2 & filter3]
filtered.sort_values(by=['dtw-python-distance'], inplace=True)
filtered
# Out:
# C:\Users\anna\miniconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#     dataType               function1  snapshot1               function2  \
# 16       CPU             aggregation          0             aggregation
# 44       CPU              filtration          1              filtration
# 14       CPU             aggregation          0             aggregation
# 18       CPU             aggregation          1             aggregation
# 42       CPU              filtration          0              filtration
# 40       CPU              filtration          0              filtration
# 70       CPU  filtration-aggregation          1  filtration-aggregation
# ...

# %% [markdown]
# ## CPU - normalized and smoothed

# %%
filter1 = distance_df["dataType"]=="CPU"
filter2 = distance_df["is_normalized"]==1
filter3 = distance_df["is_smoothed"]==1

filtered = distance_df[filter1 & filter2 & filter3]
filtered.sort_values(by=['dtaidistance'], inplace=True)
filtered
# Out:
# C:\Users\anna\miniconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#     dataType               function1  snapshot1               function2  \
# 50       CPU              filtration          1              filtration
# 20       CPU             aggregation          0             aggregation
# 22       CPU             aggregation          0             aggregation
# 76       CPU  filtration-aggregation          1  filtration-aggregation
# 72       CPU  filtration-aggregation          0  filtration-aggregation
# 24       CPU             aggregation          1             aggregation
# 126      CPU             aggregation          0  filtration-aggregation
# ...

# %% [markdown]
# ## RAM - not normalized and not smoothed

# %%
filter1 = distance_df["dataType"]=="RAM"
filter2 = distance_df["is_normalized"]==0
filter3 = distance_df["is_smoothed"]==0

filtered = distance_df[filter1 & filter2 & filter3]
#filtered.style.apply(bold_style,axis = 1)
filtered.sort_values(by=['dtw-python-distance'], inplace=True)
filtered
# Out:
# C:\Users\anna\miniconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#     dataType               function1  snapshot1               function2  \
# 1        RAM             aggregation          1             aggregation
# 27       RAM              filtration          1              filtration
# 53       RAM  filtration-aggregation          1  filtration-aggregation
# 3        RAM             aggregation          0             aggregation
# 7        RAM             aggregation          1             aggregation
# 5        RAM             aggregation          0             aggregation
# 29       RAM              filtration          0              filtration
# ...

# %% [markdown]
# ## RAM - normalized but not smoothed

# %%
filter1 = distance_df["dataType"]=="RAM"
filter2 = distance_df["is_normalized"]==1
filter3 = distance_df["is_smoothed"]==0

filtered = distance_df[filter1 & filter2 & filter3]
filtered.sort_values(by=['dtw-python-distance'], inplace=True)
filtered
# Out:
# C:\Users\anna\miniconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#     dataType               function1  snapshot1               function2  \
# 9        RAM             aggregation          0             aggregation
# 13       RAM             aggregation          1             aggregation
# 11       RAM             aggregation          0             aggregation
# 35       RAM              filtration          0              filtration
# 37       RAM              filtration          0              filtration
# 61       RAM  filtration-aggregation          0  filtration-aggregation
# 91       RAM             aggregation          0              filtration
# ...

# %% [markdown]
# ## RAM - smoothed but not normalized

# %%
filter1 = distance_df["dataType"]=="RAM"
filter2 = distance_df["is_normalized"]==0
filter3 = distance_df["is_smoothed"]==1

filtered = distance_df[filter1 & filter2 & filter3]
filtered.sort_values(by=['dtw-python-distance'], inplace=True)
filtered
# Out:
# C:\Users\anna\miniconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#     dataType               function1  snapshot1               function2  \
# 17       RAM             aggregation          0             aggregation
# 15       RAM             aggregation          0             aggregation
# 19       RAM             aggregation          1             aggregation
# 97       RAM             aggregation          0              filtration
# 41       RAM              filtration          0              filtration
# 99       RAM             aggregation          0              filtration
# 43       RAM              filtration          0              filtration
# ...

# %% [markdown]
# ## RAM - normalized and smoothed

# %%
filter1 = distance_df["dataType"]=="RAM"
filter2 = distance_df["is_normalized"]==1
filter3 = distance_df["is_smoothed"]==1

filtered = distance_df[filter1 & filter2 & filter3]
filtered.sort_values(by=['dtaidistance'], inplace=True)
filtered
# Out:
# C:\Users\anna\miniconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#     dataType               function1  snapshot1               function2  \
# 23       RAM             aggregation          0             aggregation
# 21       RAM             aggregation          0             aggregation
# 25       RAM             aggregation          1             aggregation
# 73       RAM  filtration-aggregation          0  filtration-aggregation
# 103      RAM             aggregation          0              filtration
# 105      RAM             aggregation          0              filtration
# 107      RAM             aggregation          1              filtration
# ...
